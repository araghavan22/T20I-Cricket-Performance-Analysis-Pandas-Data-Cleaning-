# %%
# Source: https://www.espncricinfo.com/records/most-runs-in-career-282827

#import pandas

# %%
import pandas as pd

# %%
#import csv

# %%
df = pd.read_csv('Python-Data-Cleaning-Cricket-Most_runs_in_T201s.csv')

# %%
df
# Out:
#                     Player       Span  Mat  Inns    NO  Runs    HS    Ave  \
# 0          RG Sharma (IND)  2007-2024  159   151  19.0  4231  121*  32.05
# 1         Babar Azam (PAK)  2016-2024  128   121  15.0  4223   122  39.83
# 2            V Kohli (IND)  2010-2024  125   117  31.0  4188  122*  48.69
# 3            V Kohli (IND)  2010-2024  125   117  31.0  4188  122*  48.69
# 4         JC Buttler (ENG)  2011-2025  137   126  23.0  3700  101*  35.92
# ..                     ...        ...  ...   ...   ...   ...   ...    ...
# 149     Sohail Ahmed (BHR)  2022-2025   49    47  17.0  1182   80*  39.40
# 150     Yuvraj Singh (IND)  2007-2017   58    51   9.0  1177   77*  28.02
# 151     KP Pietersen (ENG)  2005-2013   37    36   5.0  1176    79  37.93
# 152      DMW Rawlins (BER)  2019-2025   41    39   7.0  1169    91  36.53
# 153  Taranjeet Singh (ROM)  2021-2025   36    36   3.0  1168   110  35.39
#
#        BF      SR  100  50     0   4s   6s
# ...

# %%
# rename Multiple columns in a list

# %%
df = df.rename(columns = {'Mat': 'Matches', 'NO':'Not_Outs', 'HS': 'Highest_Inns_Score' , 'BF': 'Balls_Faced', 'SR': 'Batting_Strike_Rate' })

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0   RG Sharma (IND)  2007-2024      159   151      19.0  4231
# 1  Babar Azam (PAK)  2016-2024      128   121      15.0  4223
# 2     V Kohli (IND)  2010-2024      125   117      31.0  4188
# 3     V Kohli (IND)  2010-2024      125   117      31.0  4188
# 4  JC Buttler (ENG)  2011-2025      137   126      23.0  3700
#
#   Highest_Inns_Score    Ave  Balls_Faced  Batting_Strike_Rate  100  50     0  \
# 0               121*  32.05         3003               140.89  5.0  32  12.0
# 1                122  39.83         3268               129.22  3.0  36   7.0
# 2               122*  48.69         3056               137.04  1.0  38   7.0
# 3               122*  48.69         3056               137.04  1.0  38   7.0
# 4               101*  35.92         2516               147.05  1.0  27   8.0
#
#     4s   6s
# 0  383  205
# 1  447   73
# 2  369  124
# 3  369  124
# 4  333  160

# %%
# Check for Null Values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs                True
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                     True
# 50                     False
# 0                       True
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['100'].isna()==1]
# Out:
#                     Player       Span  Matches  Inns  Not_Outs  Runs  \
# 16      KS Williamson (NZ)  2011-2024       93    90      13.0  2575
# 17   Shakib Al Hasan (BAN)  2006-2024      129   127      17.0  2551
# 19   Mohammad Hafeez (PAK)  2006-2021      119   108      13.0  2514
# 20        EJG Morgan (ENG)  2009-2022      115   107      21.0  2458
# 21        EJG Morgan (ENG)  2009-2022      115   107      21.0  2458
# ..                     ...        ...      ...   ...       ...   ...
# 148        RG Mukasa (UGA)  2019-2024       58    56       5.0  1186
# 149     Sohail Ahmed (BHR)  2022-2025       49    47      17.0  1182
# 150     Yuvraj Singh (IND)  2007-2017       58    51       9.0  1177
# 151     KP Pietersen (ENG)  2005-2013       37    36       5.0  1176
# 152      DMW Rawlins (BER)  2019-2025       41    39       7.0  1169
#
#     Highest_Inns_Score    Ave  Balls_Faced  Batting_Strike_Rate  100  50    0  \
# ...

# %%
df['100'] = df['100'].fillna(0)

# %%
df[df['Player']== 'KS Williamson (NZ)' ]
# Out:
#                 Player       Span  Matches  Inns  Not_Outs  Runs  \
# 16  KS Williamson (NZ)  2011-2024       93    90      13.0  2575
#
#    Highest_Inns_Score    Ave  Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 16                 95  33.44         2092               123.08  0.0  18  4.0
#
#      4s  6s
# 16  245  58

# %%
df[df['0'].isna()==1]
# Out:
#                       Player       Span  Matches  Inns  Not_Outs  Runs  \
# 76           MN Samuels (WI)  2007-2018       67    65      10.0  1611
# 85  K Kadowaki-Fleming (JPN)  2022-2025       39    39       4.0  1532
# 86   F du Plessis (SA/World)  2012-2020       50    50       7.0  1528
#
#    Highest_Inns_Score    Ave  Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 76                89*  29.29         1386               116.23  0.0  10 NaN
# 85                114  43.77         1038               147.59  2.0  10 NaN
# 86                119  35.53         1137               134.38  1.0  10 NaN
#
#      4s  6s
# 76  144  69
# 85  114  79
# 86  140  50

# %%
df['0'] = df['0'].fillna(0)

# %%
df[df['Player']== 'MN Samuels (WI)' ]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 76  MN Samuels (WI)  2007-2018       67    65      10.0  1611
#
#    Highest_Inns_Score    Ave  Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 76                89*  29.29         1386               116.23  0.0  10  0.0
#
#      4s  6s
# 76  144  69

# %%
df[df['Not_Outs'].isna()==1]
# Out:
#                        Player       Span  Matches  Inns  Not_Outs  Runs  \
# 67   Rahmanullah Gurbaz (AFG)  2019-2024       66    66       NaN  1683
# 103            J Charles (WI)  2011-2025       63    62       NaN  1433
#
#     Highest_Inns_Score    Ave  Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 67                 100  25.50         1252               134.42  1.0  10  8.0
# 103                118  23.11         1100               130.27  1.0   5  7.0
#
#       4s  6s
# 67   128  95
# 103  155  67

# %%
df['Not_Outs'] = df['Not_Outs'].fillna(0)

# %%
df[df['Player']== 'J Charles (WI)' ]
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 103  J Charles (WI)  2011-2025       63    62       0.0  1433
#
#     Highest_Inns_Score    Ave  Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 103                118  23.11         1100               130.27  1.0   5  7.0
#
#       4s  6s
# 103  155  67

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
# drop duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 149    False
# 150    False
# 151    False
# 152    False
# 153    False
# Length: 154, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 3       V Kohli (IND)  2010-2024      125   117      31.0  4188
# 21   EJG Morgan (ENG)  2009-2022      115   107      21.0  2458
# 48      CH Gayle (WI)  2006-2021       79    75       7.0  1899
# 148   RG Mukasa (UGA)  2019-2024       58    56       5.0  1186
#
#     Highest_Inns_Score    Ave  Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 3                 122*  48.69         3056               137.04  1.0  38  7.0
# 21                  91  28.58         1805               136.17  0.0  14  3.0
# 48                 117  27.92         1381               137.50  2.0  14  4.0
# 148                 89  23.25          982               120.77  0.0   5  8.0
#
#       4s   6s
# 3    369  124
# 21   186  120
# 48   158  124
# 148  133   36

# %%
df[df['Player'].isin(['V Kohli (IND)','EJG Morgan (ENG)', 'CH Gayle (WI)', 'RG Mukasa (UGA)'])]
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 2       V Kohli (IND)  2010-2024      125   117      31.0  4188
# 3       V Kohli (IND)  2010-2024      125   117      31.0  4188
# 20   EJG Morgan (ENG)  2009-2022      115   107      21.0  2458
# 21   EJG Morgan (ENG)  2009-2022      115   107      21.0  2458
# 47      CH Gayle (WI)  2006-2021       79    75       7.0  1899
# 48      CH Gayle (WI)  2006-2021       79    75       7.0  1899
# 147   RG Mukasa (UGA)  2019-2024       58    56       5.0  1186
# 148   RG Mukasa (UGA)  2019-2024       58    56       5.0  1186
#
#     Highest_Inns_Score    Ave  Balls_Faced  Batting_Strike_Rate  100  50    0  \
# 2                 122*  48.69         3056               137.04  1.0  38  7.0
# 3                 122*  48.69         3056               137.04  1.0  38  7.0
# 20                  91  28.58         1805               136.17  0.0  14  3.0
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                     Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0          RG Sharma (IND)  2007-2024      159   151      19.0  4231
# 1         Babar Azam (PAK)  2016-2024      128   121      15.0  4223
# 2            V Kohli (IND)  2010-2024      125   117      31.0  4188
# 4         JC Buttler (ENG)  2011-2025      137   126      23.0  3700
# 5        PR Stirling (IRE)  2009-2025      151   148      11.0  3669
# ..                     ...        ...      ...   ...       ...   ...
# 149     Sohail Ahmed (BHR)  2022-2025       49    47      17.0  1182
# 150     Yuvraj Singh (IND)  2007-2017       58    51       9.0  1177
# 151     KP Pietersen (ENG)  2005-2013       37    36       5.0  1176
# 152      DMW Rawlins (BER)  2019-2025       41    39       7.0  1169
# 153  Taranjeet Singh (ROM)  2021-2025       36    36       3.0  1168
#
#     Highest_Inns_Score    Ave  Balls_Faced  Batting_Strike_Rate  100  50  \
# ...

# %%
# Split up Span into Start and End Date

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0      [2007, 2024]
# 1      [2016, 2024]
# 2      [2010, 2024]
# 4      [2011, 2025]
# 5      [2009, 2025]
#            ...
# 149    [2022, 2025]
# 150    [2007, 2017]
# 151    [2005, 2013]
# 152    [2019, 2025]
# 153    [2021, 2025]
# Name: Span, Length: 150, dtype: object

# %%
df['Span'].str.split(pat = '-').str[0]
# Out:
# 0      2007
# 1      2016
# 2      2010
# 4      2011
# 5      2009
#        ...
# 149    2022
# 150    2007
# 151    2005
# 152    2019
# 153    2021
# Name: Span, Length: 150, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                     Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0          RG Sharma (IND)  2007-2024      159   151      19.0  4231
# 1         Babar Azam (PAK)  2016-2024      128   121      15.0  4223
# 2            V Kohli (IND)  2010-2024      125   117      31.0  4188
# 4         JC Buttler (ENG)  2011-2025      137   126      23.0  3700
# 5        PR Stirling (IRE)  2009-2025      151   148      11.0  3669
# ..                     ...        ...      ...   ...       ...   ...
# 149     Sohail Ahmed (BHR)  2022-2025       49    47      17.0  1182
# 150     Yuvraj Singh (IND)  2007-2017       58    51       9.0  1177
# 151     KP Pietersen (ENG)  2005-2013       37    36       5.0  1176
# 152      DMW Rawlins (BER)  2019-2025       41    39       7.0  1169
# 153  Taranjeet Singh (ROM)  2021-2025       36    36       3.0  1168
#
#     Highest_Inns_Score    Ave  Balls_Faced  Batting_Strike_Rate  100  50  \
# ...

# %%
# Drop Span Column

# %%
df = df.drop(['Span'], axis = 1)

# %%
df.head()
# Out:
#               Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    RG Sharma (IND)      159   151      19.0  4231               121*  32.05
# 1   Babar Azam (PAK)      128   121      15.0  4223                122  39.83
# 2      V Kohli (IND)      125   117      31.0  4188               122*  48.69
# 4   JC Buttler (ENG)      137   126      23.0  3700               101*  35.92
# 5  PR Stirling (IRE)      151   148      11.0  3669               115*  26.78
#
#    Balls_Faced  Batting_Strike_Rate  100  50     0   4s   6s Rookie_Year  \
# 0         3003               140.89  5.0  32  12.0  383  205        2007
# 1         3268               129.22  3.0  36   7.0  447   73        2016
# 2         3056               137.04  1.0  38   7.0  369  124        2010
# 4         2516               147.05  1.0  27   8.0  333  160        2011
# 5         2720               134.88  1.0  24  13.0  428  129        2009
#
#   Final_Year
# 0       2024
# 1       2024
# 2       2024
# ...

# %%
# Split up Country from Player

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0            [RG Sharma , IND)]
# 1           [Babar Azam , PAK)]
# 2              [V Kohli , IND)]
# 4           [JC Buttler , ENG)]
# 5          [PR Stirling , IRE)]
#                  ...
# 149       [Sohail Ahmed , BHR)]
# 150       [Yuvraj Singh , IND)]
# 151       [KP Pietersen , ENG)]
# 152        [DMW Rawlins , BER)]
# 153    [Taranjeet Singh , ROM)]
# Name: Player, Length: 150, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country']
# Out:
# 0      IND)
# 1      PAK)
# 2      IND)
# 4      ENG)
# 5      IRE)
#        ...
# 149    BHR)
# 150    IND)
# 151    ENG)
# 152    BER)
# 153    ROM)
# Name: Country, Length: 150, dtype: object

# %%
 df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df['Country']
# Out:
# 0      IND
# 1      PAK
# 2      IND
# 4      ENG
# 5      IRE
#       ...
# 149    BHR
# 150    IND
# 151    ENG
# 152    BER
# 153    ROM
# Name: Country, Length: 150, dtype: object

# %%
df.head()
# Out:
#               Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    RG Sharma (IND)      159   151      19.0  4231               121*  32.05
# 1   Babar Azam (PAK)      128   121      15.0  4223                122  39.83
# 2      V Kohli (IND)      125   117      31.0  4188               122*  48.69
# 4   JC Buttler (ENG)      137   126      23.0  3700               101*  35.92
# 5  PR Stirling (IRE)      151   148      11.0  3669               115*  26.78
#
#    Balls_Faced  Batting_Strike_Rate  100  50     0   4s   6s Rookie_Year  \
# 0         3003               140.89  5.0  32  12.0  383  205        2007
# 1         3268               129.22  3.0  36   7.0  447   73        2016
# 2         3056               137.04  1.0  38   7.0  369  124        2010
# 4         2516               147.05  1.0  27   8.0  333  160        2011
# 5         2720               134.88  1.0  24  13.0  428  129        2009
#
#   Final_Year Country
# 0       2024     IND
# ...

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    RG Sharma       159   151      19.0  4231               121*  32.05
# 1   Babar Azam       128   121      15.0  4223                122  39.83
# 2      V Kohli       125   117      31.0  4188               122*  48.69
# 4   JC Buttler       137   126      23.0  3700               101*  35.92
# 5  PR Stirling       151   148      11.0  3669               115*  26.78
#
#    Balls_Faced  Batting_Strike_Rate  100  50     0   4s   6s Rookie_Year  \
# 0         3003               140.89  5.0  32  12.0  383  205        2007
# 1         3268               129.22  3.0  36   7.0  447   73        2016
# 2         3056               137.04  1.0  38   7.0  369  124        2010
# 4         2516               147.05  1.0  27   8.0  333  160        2011
# 5         2720               134.88  1.0  24  13.0  428  129        2009
#
#   Final_Year Country
# 0       2024     IND
# 1       2024     PAK
# ...

# %%
# Change DataTypes

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs               float64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                    float64
# 50                       int64
# 0                      float64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat = '*').str[0]
# Out:
# 0      121
# 1      122
# 2      122
# 4      101
# 5      115
#       ...
# 149     80
# 150     77
# 151     79
# 152     91
# 153    110
# Name: Highest_Inns_Score, Length: 150, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Score'].astype('int')
# Out:
# 0      121
# 1      122
# 2      122
# 4      101
# 5      115
#       ...
# 149     80
# 150     77
# 151     79
# 152     91
# 153    110
# Name: Highest_Inns_Score, Length: 150, dtype: int32

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int64')

# %%
# Change data types for Rookie_Year, Final_Year, Not_Outs, 100 and 0

# %%
df  = df.astype({'Rookie_Year':'int', 'Final_Year':'int',  'Not_Outs':'int64', '100':'int64', '0':'int64'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# dtype: object

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                   Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score  \
# 0             RG Sharma       159   151        19  4231                 121
# 1            Babar Azam       128   121        15  4223                 122
# 2               V Kohli       125   117        31  4188                 122
# 4            JC Buttler       137   126        23  3700                 101
# 5           PR Stirling       151   148        11  3669                 115
# 6            MJ Guptill       122   118         7  3531                 105
# 7       Mohammad Rizwan       106    93        21  3414                 104
# 8             DA Warner       110   110        12  3277                 100
# 9              AJ Finch       103   103        12  3120                 172
# 10      Virandeep Singh        95    92        17  2769                 116
# 11           GJ Maxwell       116   106        17  2664                 145
# ...

# %%
# Drop last row

# %%
df = df.drop(153, axis = 0)

# %%
df
# Out:
#                   Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score  \
# 0             RG Sharma       159   151        19  4231                 121
# 1            Babar Azam       128   121        15  4223                 122
# 2               V Kohli       125   117        31  4188                 122
# 4            JC Buttler       137   126        23  3700                 101
# 5           PR Stirling       151   148        11  3669                 115
# 6            MJ Guptill       122   118         7  3531                 105
# 7       Mohammad Rizwan       106    93        21  3414                 104
# 8             DA Warner       110   110        12  3277                 100
# 9              AJ Finch       103   103        12  3120                 172
# 10      Virandeep Singh        95    92        17  2769                 116
# 11           GJ Maxwell       116   106        17  2664                 145
# ...

# %%
# Build Career_Length Column for all Players

# %%
df['Career_Length'] = df['Final_Year'] - df['Rookie_Year']

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0    RG Sharma       159   151        19  4231                 121  32.05
# 1   Babar Azam       128   121        15  4223                 122  39.83
# 2      V Kohli       125   117        31  4188                 122  48.69
# 4   JC Buttler       137   126        23  3700                 101  35.92
# 5  PR Stirling       151   148        11  3669                 115  26.78
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0   4s   6s  Rookie_Year  \
# 0         3003               140.89    5  32  12  383  205         2007
# 1         3268               129.22    3  36   7  447   73         2016
# 2         3056               137.04    1  38   7  369  124         2010
# 4         2516               147.05    1  27   8  333  160         2011
# 5         2720               134.88    1  24  13  428  129         2009
#
#    Final_Year Country  Career_Length
# 0        2024     IND             17
# ...

# %%
# ANSWER THE FOLLOWING QUESTIONS - CALCULATIONS WITHIN THE DATAFRAME

# %%
# Question 1: What is the average Career_Length of the Cricketers in this DataFrame?

# %%
df['Career_Length'].mean()
# Out:
# 9.409395973154362

# %%
# Question 2: What is the average Batting_Strike_Rate of the Cricketers who played over 10 years?

# %%
df[df['Career_Length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# 129.05310344827583

# %%
# Question 3: How many cricketers played before 2008?

# %%
df[df['Rookie_Year'] < 2008]['Player'].count()
# Out:
# 27

# %%
# Question 4: What are the top 5 Highest_Inns_Score?

# %%
df['Highest_Inns_Score'].nlargest(n=5)
# Out:
# 9      172
# 11     145
# 125    137
# 24     133
# 37     133
# Name: Highest_Inns_Score, dtype: int64

# %%
# Question 5: What are the top 5 Highest_Inns_Score? List Rows with all the details

# %%
df.sort_values('Highest_Inns_Score', ascending=False).head(5)
# Out:
#              Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 9         AJ Finch       103   103        12  3120                 172  34.28
# 11      GJ Maxwell       116   106        17  2664                 145  29.93
# 125       FH Allen        52    52         1  1285                 137  25.19
# 37       MP O'Dowd        80    78         5  2074                 133  28.41
# 24   Sikandar Raza       105   100         7  2403                 133  25.83
#
#      Balls_Faced  Batting_Strike_Rate  100  50  0   4s   6s  Rookie_Year  \
# 9           2189               142.53    2  19  8  309  125         2011
# 11          1719               154.97    5  11  4  224  137         2012
# 125          787               163.27    2   5  5  113   89         2021
# 37          1711               121.21    1  14  2  216   50         2015
# 24          1766               136.07    1  14  8  180  117         2013
#
#      Final_Year Country  Career_Length
# ...

# %%
# Question 6: What are the top Highest_Inns_Score by country?

# %%
df.groupby('Country')['Highest_Inns_Score'].max()
# Out:
# Country
# AFG              118
# AUS              172
# AUS/SGP           92
# AUT               95
# BAN               84
# BAN/ICC/World    103
# BER               91
# BHR               80
# BOT               84
# CAN               70
# ENG              119
# HKG              122
# HKG/NZ           104
# ICC/PAK           75
# ICC/SL/World      61
# IND              122
# IRE              124
# JER               96
# JPN              114
# KENYA            120
# KSA              110
# KUW              103
# MAS              126
# MLT              104
# MWI               94
# NAM              100
# NED              133
# NEP              110
# NZ               137
# OMA              102
# PAK              122
# PNG              107
# QAT               88
# ROM               99
# RWN              100
# SA               117
# SA/World         119
# SCOT             132
# SL               104
# TAN               81
# UAE              112
# UGA              100
# WI               125
# ...

# %%
# Question 6: Convert the above into a DataFrame with 2 columns for Country and Highest_Inns

# %%
df_result = df.groupby('Country')['Highest_Inns_Score'].max().reset_index()
df_result.columns = ['Country', 'Highest_Inns']
df_result
# Out:
#           Country  Highest_Inns
# 0             AFG           118
# 1             AUS           172
# 2         AUS/SGP            92
# 3             AUT            95
# 4             BAN            84
# 5   BAN/ICC/World           103
# 6             BER            91
# 7             BHR            80
# 8             BOT            84
# 9             CAN            70
# 10            ENG           119
# 11            HKG           122
# 12         HKG/NZ           104
# 13        ICC/PAK            75
# 14   ICC/SL/World            61
# 15            IND           122
# 16            IRE           124
# 17            JER            96
# 18            JPN           114
# 19          KENYA           120
# 20            KSA           110
# 21            KUW           103
# 22            MAS           126
# 23            MLT           104
# 24            MWI            94
# 25            NAM           100
# 26            NED           133
# 27            NEP           110
# ...

# %%
# Question 7: What are the top 10 Highest_Inns_Score by country? -- Convert the above into a DataFrame

# %%
df_result.sort_values('Highest_Inns', ascending=False).head(10)
# Out:
#    Country  Highest_Inns
# 1      AUS           172
# 28      NZ           137
# 43     ZIM           133
# 26     NED           133
# 37    SCOT           132
# 22     MAS           126
# 42      WI           125
# 16     IRE           124
# 30     PAK           122
# 15     IND           122

# %%
# Question 8: What are the averages of Hundreds, Fifties and ducks (0) by Country?

# %%
df.groupby('Country')[['100', '50', '0']].mean()
# Out:
#                     100         50          0
# Country
# AFG            0.400000   8.000000   6.200000
# AUS            1.285714  12.142857   3.714286
# AUS/SGP        0.000000   6.000000   4.000000
# AUT            0.000000   8.000000   4.000000
# BAN            0.000000   8.600000   8.200000
# BAN/ICC/World  1.000000   7.000000   6.000000
# BER            0.000000   9.000000   2.000000
# BHR            0.000000   8.500000   3.000000
# BOT            0.000000   8.000000   2.000000
# CAN            0.000000   9.000000   2.000000
# ENG            0.666667  11.777778   5.000000
# HKG            0.666667   9.333333   5.333333
# HKG/NZ         1.000000   9.000000   3.000000
# ICC/PAK        0.000000   6.500000   5.000000
# ICC/SL/World   0.000000   3.000000   8.000000
# IND            1.300000  14.700000   4.300000
# IRE            0.285714   8.571429   7.857143
# JER            0.000000   7.000000   5.000000
# JPN            2.000000  10.000000   0.000000
# ...
